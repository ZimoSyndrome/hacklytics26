# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
load_path = 'data/processed/audio_call_matrix.csv'
audio = pd.read_csv(load_path)
print(audio.shape)
audio.head()
# Out:
# (3443, 206)
#      instance_id ticker   call_date  mean_Mean pitch  mean_Standard deviation  \
# 0  20150225_LMAT   LMAT  2015-02-25       128.306624                62.107333
# 1  20150226_ACIW   ACIW  2015-02-26       180.028782                86.252295
# 2  20150226_ADSK   ADSK  2015-02-26       149.335950                43.851317
# 3  20150226_AMWD   AMWD  2015-02-26       126.843933                68.476689
# 4  20150226_ANSS   ANSS  2015-02-26       167.354891                73.969350
#
#    mean_Minimum pitch  mean_Maximum pitch  mean_Mean intensity  \
# 0           85.507267          459.584076            50.509184
# 1           85.077513          469.965090            55.346909
# 2           96.058017          366.591867            54.678148
# 3           86.869222          459.917133            49.005347
# 4           90.991058          524.365723            56.302637
#
#    mean_Minimum intensity  mean_Maximum intensity  ...  slope_Shimmer local  \
# 0               68.939125               20.747126  ...            -2.330198
# 1               76.872280               30.401423  ...            -3.407318
# 2               71.869477               23.883329  ...            -5.493085
# 3               69.939225               17.778132  ...            -2.441777
# 4               71.844446               11.483946  ...            -1.745179
#
#    slope_Shimmer local dB  slope_Shimmer apq3  slope_Shimmer apq5  \
# 0               -0.132341           -1.305716           -1.062710
# 1               -0.286175           -1.736174           -1.860018
# 2               -0.404579           -1.801149           -1.450769
# 3               -0.147170           -1.765048           -2.220593
# 4               -0.110823           -0.319652           -0.965877
#
#    slope_Shimmer apq11  slope_Shimmer dda  slope_Mean autocorrelation  \
# 0            -0.066187          -3.917266                    0.047600
# 1            -1.867566          -5.208951                    0.056797
# 2            -3.870413          -5.403370                   -0.057257
# 3             0.022430          -5.295544                    0.058308
# 4            -2.629804          -0.959063                   -0.038944
#
#    slope_Mean NHR  slope_Mean HNR  slope_Audio Length
# 0       -0.089319        1.551691            0.539950
# 1       -0.097081        2.265290            1.762820
# 2       -0.162725        0.784716           -1.591003
# 3       -0.112731        1.714723           -0.104369
# 4        0.080924       -0.993872            0.217071
#
# [5 rows x 206 columns]

# %%
load_path = 'data/processed/text_call_matrix.csv'
text = pd.read_csv(load_path)
print(text.shape)
text.head()
# Out:
# (3443, 2691)
#      instance_id ticker   call_date   mean_e0   mean_e1   mean_e2   mean_e3  \
# 0  20150225_LMAT   LMAT  2015-02-25  0.007288  0.000998  0.003222 -0.008416
# 1  20150226_ACIW   ACIW  2015-02-26 -0.010614 -0.003885  0.005300 -0.021778
# 2  20150226_ADSK   ADSK  2015-02-26 -0.024106 -0.013536  0.010253 -0.009161
# 3  20150226_AMWD   AMWD  2015-02-26  0.004546 -0.019589  0.013683  0.013155
# 4  20150226_ANSS   ANSS  2015-02-26 -0.006074 -0.020038  0.010920 -0.017417
#
#     mean_e4   mean_e5   mean_e6  ...  slope_e374  slope_e375  slope_e376  \
# 0 -0.002437 -0.003212 -0.021679  ...    0.028887   -0.020466    0.008103
# 1  0.003938 -0.011949 -0.017517  ...   -0.019642   -0.003559    0.026505
# 2  0.025073  0.000895 -0.002943  ...   -0.036131    0.009026    0.070006
# 3  0.024236  0.005180 -0.040526  ...   -0.021931   -0.002852    0.003339
# 4  0.007784 -0.002698 -0.031453  ...   -0.009045    0.004114   -0.030518
#
#    slope_e377  slope_e378  slope_e379  slope_e380  slope_e381  slope_e382  \
# 0    0.015459   -0.024659    0.012380    0.016544   -0.027073   -0.007075
# 1    0.018677    0.009102    0.039975    0.032946    0.048909    0.066477
# 2   -0.017932    0.051465    0.013141   -0.011438    0.019301   -0.018877
# 3    0.021923    0.024523   -0.006380    0.027933   -0.019496   -0.004593
# 4    0.000137    0.008410    0.000306   -0.000478   -0.021842    0.032748
#
#    slope_e383
# 0   -0.015799
# 1   -0.001588
# 2    0.004766
# 3    0.000105
# 4   -0.001392
#
# [5 rows x 2691 columns]

# %%
X =
